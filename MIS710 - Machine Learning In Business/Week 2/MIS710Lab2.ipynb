# %% [markdown]
# <a href="https://colab.research.google.com/github/thwc/MIS710-T12023/blob/main/Week%202/MIS710Lab2-Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MIS710 Lab 2 Week 2**
# Author: Associate Professor Lemai Nguyen, Thuc Nguyen
#
# Objective: to learn Python bacis and load a dataset to view its shape and data types, and to perform Exploratory Data Analysis (EDA)

# %% [markdown]
# **To do before the class:**
# 1. read the Lab slides
# 2. access Colab
# 3. make sure you have a google account, and Drive
# 4. download the titanic dataset and store it in your Google drive

# %% [markdown]
# **Student name:**
#
# Student ID:

# %% [markdown]
# # **Task 1: Titanic dataset**
# Dataset: Titanic
#
# Source: https://www.kaggle.com/c/titanic

# %% [markdown]
# ## **Import Libraries**

# %%
#load libraries
import pandas as pd #for data manipulation and analysis
import numpy as np #for working with arrays

#import data visualisation libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Mount your Google drive**

# %% [markdown]
# As we upload the datasets from github, you can skip the following code for this Lab. However, you should be able to mount your google drive to upload your assignment datasets.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Load Data**
#
#
# 1.   Load the dataset
# 2.   Explore the data

# %%
# load dataset stored in your Google drive, OR use our Github file
records = pd.read_csv("https://raw.githubusercontent.com/ABAL-DU/MIS710_2024_T1/main/Week%202/titanic_train.csv")

#explore the dataset
print(records)

print('Sample size:', records.shape[0])
print('Number of columns:', records.shape[1])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]
# Sample size: 891
# Number of columns: 12

# %% [markdown]
# ## **Inspect data at a glance**

# %%
print(records.info())
print(records.shape)

#What is displayed?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
# (891, 12)

# %%
records.head()
#What is displayed?
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
records.tail(10)
#What is displayed?
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %%
records.sample(10)
#What is displayed?

##write your code to inspect 20 samples
# Out:
#      PassengerId  Survived  Pclass  \
# 706          707         1       2
# 844          845         0       3
# 694          695         0       1
# 368          369         1       3
# 492          493         0       1
# 621          622         1       1
# 534          535         0       3
# 339          340         0       1
# 785          786         0       3
# 46            47         0       3
# 769          770         0       3
# 357          358         0       2
# 67            68         0       3
# 862          863         1       1
# 742          743         1       1
# 506          507         1       2
# 641          642         1       1
# 280          281         0       3
# 79            80         1       3
# 103          104         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 706                      Kelly, Mrs. Florence "Fannie"  female  45.0      0
# 844                                Culumovic, Mr. Jeso    male  17.0      0
# 694                                    Weir, Col. John    male  60.0      0
# 368                                Jermyn, Miss. Annie  female   NaN      0
# 492                         Molson, Mr. Harry Markland    male  55.0      0
# 621                       Kimball, Mr. Edwin Nelson Jr    male  42.0      1
# 534                                Cacic, Miss. Marija  female  30.0      0
# 339                       Blackwell, Mr. Stephen Weart    male  45.0      0
# 785                 Harmer, Mr. Abraham (David Lishin)    male  25.0      0
# 46                                   Lennon, Mr. Denis    male   NaN      1
# 769                   Gronnestad, Mr. Daniel Danielsen    male  32.0      0
# 357                          Funk, Miss. Annie Clemmer  female  38.0      0
# 67                            Crease, Mr. Ernest James    male  19.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 742              Ryerson, Miss. Susan Parker "Suzette"  female  21.0      2
# 506      Quick, Mrs. Frederick Charles (Jane Richards)  female  33.0      0
# 641                               Sagesser, Mlle. Emma  female  24.0      0
# 280                                   Duane, Mr. Frank    male  65.0      0
# 79                            Dowdell, Miss. Elizabeth  female  30.0      0
# 103                         Johansson, Mr. Gustaf Joel    male  33.0      0
#
#      Parch     Ticket      Fare            Cabin Embarked
# 706      0     223596   13.5000              NaN        S
# 844      0     315090    8.6625              NaN        S
# 694      0     113800   26.5500              NaN        S
# 368      0      14313    7.7500              NaN        Q
# 492      0     113787   30.5000              C30        S
# 621      0      11753   52.5542              D19        S
# 534      0     315084    8.6625              NaN        S
# 339      0     113784   35.5000                T        S
# 785      0     374887    7.2500              NaN        S
# 46       0     370371   15.5000              NaN        Q
# 769      0       8471    8.3625              NaN        S
# 357      0     237671   13.0000              NaN        S
# 67       0  S.P. 3464    8.1583              NaN        S
# 862      0      17466   25.9292              D17        S
# 742      2   PC 17608  262.3750  B57 B59 B63 B66        C
# 506      2      26360   26.0000              NaN        S
# 641      0   PC 17477   69.3000              B35        C
# 280      0     336439    7.7500              NaN        Q
# 79       0     364516   12.4750              NaN        S
# 103      0       7540    8.6542              NaN        S

# %%
#print first five data points from a certain column(s)
names= records[['Name','Survived']]
print(names.head(5))
# Out:
#                                                 Name  Survived
# 0                            Braund, Mr. Owen Harris         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                             Heikkinen, Miss. Laina         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                           Allen, Mr. William Henry         0

# %%
#print first five data points from your addtionally selected column(s)
print(records[['Name', 'Sex', 'Age','Survived']].head(5))
# Out:
#                                                 Name     Sex   Age  Survived
# 0                            Braund, Mr. Owen Harris    male  22.0         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0         1
# 2                             Heikkinen, Miss. Laina  female  26.0         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0         1
# 4                           Allen, Mr. William Henry    male  35.0         0

# %% [markdown]
# ## **Inspect missing data**
#
# The data preprocessing is cyclic with analysing and visualising data, handling missing data, and feature engineering. For the learning purpose, we show you some simple techniques, you should move between the activities yourself.

# %%
#Learn to use for loop, and accessing elements of a dataframe using iloc
#Count missing data
for i in records.iloc[:,0:13]:
  miss=records[i].isna().sum()
  print(i,'missing: ', miss)
# Out:
# PassengerId missing:  0
# Survived missing:  0
# Pclass missing:  0
# Name missing:  0
# Sex missing:  0
# Age missing:  177
# SibSp missing:  0
# Parch missing:  0
# Ticket missing:  0
# Fare missing:  0
# Cabin missing:  687
# Embarked missing:  2

# %%
#another way to find missing data is using the function isnull()
#read about isnull() here https://pandas.pydata.org/docs/reference/api/pandas.isnull.html
#useful site: https://www.sharpsightlabs.com/blog/pandas-isnull/
print(records.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## **Conduct Exploratory Data Analysis - EDA**
#
# Stats and visualtion
# 1.  Univariate analysis
# 2.  Bivariate analysis
# 3.  Multivariate analysis

# %% [markdown]
# ### **Univariate analysis**

# %% [markdown]
# **Univariate analysis explores centrality, summarise and visualises data distribution for each variable at a time**

# %%
#descriptive stats for numerical variables
records.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Run the above code and write down here your observations:
# For example, centrality of age distribution, range, and std.
#
# What can you say about some other columns, for example PassengerID and Survived does it make sense?

# %%
#set the formatting for floating numbers
pd.set_option('display.float_format', lambda x: '%.3f' % x)

#summarise categorical columns as well
data_types =['object', 'float', 'int']
records.describe(include=data_types)
# Out:
#         PassengerId  Survived  Pclass                     Name   Sex     Age  \
# count       891.000   891.000 891.000                      891   891 714.000
# unique          NaN       NaN     NaN                      891     2     NaN
# top             NaN       NaN     NaN  Braund, Mr. Owen Harris  male     NaN
# freq            NaN       NaN     NaN                        1   577     NaN
# mean        446.000     0.384   2.309                      NaN   NaN  29.699
# std         257.354     0.487   0.836                      NaN   NaN  14.526
# min           1.000     0.000   1.000                      NaN   NaN   0.420
# 25%         223.500     0.000   2.000                      NaN   NaN  20.125
# 50%         446.000     0.000   3.000                      NaN   NaN  28.000
# 75%         668.500     1.000   3.000                      NaN   NaN  38.000
# max         891.000     1.000   3.000                      NaN   NaN  80.000
#
#          SibSp   Parch  Ticket    Fare    Cabin Embarked
# count  891.000 891.000     891 891.000      204      889
# unique     NaN     NaN     681     NaN      147        3
# top        NaN     NaN  347082     NaN  B96 B98        S
# freq       NaN     NaN       7     NaN        4      644
# mean     0.523   0.382     NaN  32.204      NaN      NaN
# std      1.103   0.806     NaN  49.693      NaN      NaN
# min      0.000   0.000     NaN   0.000      NaN      NaN
# 25%      0.000   0.000     NaN   7.910      NaN      NaN
# 50%      0.000   0.000     NaN  14.454      NaN      NaN
# 75%      1.000   0.000     NaN  31.000      NaN      NaN
# max      8.000   6.000     NaN 512.329      NaN      NaN

# %% [markdown]
# **Explore each numerical variable**

# %%
#explore each numerical variable
print('Age mean: ', (records['Age'].mean()))
print('Age meadian: ', (records['Age'].median()))
print('Age min: ', (records['Age'].min()))
print('Age max: ', (records['Age'].max()))
print('Age std: ', (records['Age'].std()))
# Out:
# Age mean:  29.69911764705882
# Age meadian:  28.0
# Age min:  0.42
# Age max:  80.0
# Age std:  14.526497332334042

# %%
#Visualise a numerical variable using histrograms using matplot
records.Age.hist()
# Out:
# <Axes: >

# %%
#let's specify the histogram
records['Age'].plot.hist(grid=True, bins=10, rwidth=2, color='#607e9f')
plt.title('Age of passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
#using seaborn https://seaborn.pydata.org/generated/seaborn.histplot.html
sns.histplot(data=records, x='Age', bins=50, kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#We can also use seaborn
import seaborn as sns

# Assuming you have already computed the 'ages' variable containing the age values

# Calculate the number of bins
num_bins = int(max(records['Age']) - min(records['Age']) + 1)

# Create the histogram with each bin representing 1 age
sns.histplot(data=records, x='Age', bins=num_bins, kde=True)

# Display the plot
plt.show()

# %%
sns.boxplot(x=records['Age'], color='blue')
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(x=records['Age'], color='orange')
# Out:
# <Axes: xlabel='Age'>

# %%
sns.swarmplot(x=records['Age'], color='brown')
sns.violinplot(x=records['Age'], color='orange')
# Out:
# <Axes: xlabel='Age'>

# %%
sns.kdeplot(x=records['Age'], color='orange')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# **It's your turn: explore other numerical variables**

# %%
##write your code to explore Fare yourself
# Out:
# count   891.000
# mean     32.204
# std      49.693
# min       0.000
# 25%       7.910
# 50%      14.454
# 75%      31.000
# max     512.329
# Name: Fare, dtype: float64

# %%
##write your code to visualise Fare yourself

# %% [markdown]
# **Explore each categorical variable**

# %%
#describe categorical variables
print(records['Sex'].describe(include='object'))
print(records['Embarked'].describe())

#run the code and answer: what does the result cell say?
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
#explore each categorial variable
print(records['Embarked'].value_counts())
print('Embarked mode: ', records['Embarked'].mode())
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
# Embarked mode:  0    S
# Name: Embarked, dtype: object

# %%
#Another way to do it
records.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
##write your code to explore other categorial variables yourself, for example Sex
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# **Visualise each categorical variable**

# %%
#Using seaborn
sns.countplot(x=records['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
##write your code to visualise the distribution of Sex and other categorical variables
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# **Visualise other categorical variables using a loop**

# %%
for i in ['Survived','Pclass', 'Sex', 'Embarked']:
   plt.figure()
   sns.countplot(x=records[i])

# %% [markdown]
# **You can use stats results to handle missing data**

# %%
#Fill in missing numerical data with mean and categorical data with mode
records['Age'].fillna(records['Age'].mean(),inplace=True)
records['Embarked'].fillna(records['Embarked'].mode()[0], inplace=True) #there can be more than one mode

# %%
print(records.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# **Explore these variables after you have filled in the missing data**

# %% [markdown]
# Drop irrelevant rows. For example

# %%
records.drop(['PassengerId','Name'], axis=1, inplace=True)
print(records.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Cabin     204 non-null    object
#  9   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB
# None

# %%
#You can drop rows with missing data
records.dropna(subset=['Embarked'], inplace=True)
print(records.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Cabin     204 non-null    object
#  9   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB
# None

# %% [markdown]
# **Do it yourself**

# %%
##write your code to check for missing data again. Are there still missing data, why?
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      0
# dtype: int64

# %% [markdown]
# **Note** We can remove all rows with any missing data as follows - but we don't do it as we don't use Cabin number in Analysis. What would be the impact if we do?
#
#
# ```
# records.dropna(inplace=True)
# ```

# %% [markdown]
# ### **Bivariate analysis**

# %% [markdown]
# **Display a countplot for one categorical variable grouped by a second categorical variable**
# https://seaborn.pydata.org/generated/seaborn.countplot.html

# %%
sns.countplot(data=records, x='Sex', hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
##write your code to visualuse the distribution of Survival by Sex
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# **Compare distributions of numerical variables using boxplots**
# https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
sns.boxplot(data=records, x='Age', y='Embarked')
# Out:
# <Axes: xlabel='Age', ylabel='Embarked'>

# %%
##write your code to visualuse the distribution of Age by Survival
# Out:
# <Axes: xlabel='Age', ylabel='Embarked'>

# %%
#Another way to visualise the Age distribution by Survival status
sns.kdeplot(data=records, x="Age", hue="Survived", multiple="stack")
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# **Ploting diagram to see relationships between two numerical variables**
# https://seaborn.pydata.org/generated/seaborn.scatterplot.html

# %%
sns.scatterplot(data=records, x='Age', y='Fare')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
#adding regression line
sns.regplot(data=records, x='Age', y='Fare')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# ### **Data conversion**

# %%
#Import LabelEncoder
from sklearn.preprocessing import LabelEncoder

# %%
# convert categorical variables to numerical using LabelEncoder
encoder = LabelEncoder()
records['Sex_N'] = encoder.fit_transform(records['Sex'])
records['Embarked_N'] = encoder.fit_transform(records['Embarked'])

# %%
records.tail(20)
# Out:
#      Survived  Pclass     Sex    Age  SibSp  Parch            Ticket   Fare  \
# 871         1       1  female 47.000      1      1             11751 52.554
# 872         0       1    male 33.000      0      0               695  5.000
# 873         0       3    male 47.000      0      0            345765  9.000
# 874         1       2  female 28.000      1      0         P/PP 3381 24.000
# 875         1       3  female 15.000      0      0              2667  7.225
# 876         0       3    male 20.000      0      0              7534  9.846
# 877         0       3    male 19.000      0      0            349212  7.896
# 878         0       3    male 29.699      0      0            349217  7.896
# 879         1       1  female 56.000      0      1             11767 83.158
# 880         1       2  female 25.000      0      1            230433 26.000
# 881         0       3    male 33.000      0      0            349257  7.896
# 882         0       3  female 22.000      0      0              7552 10.517
# 883         0       2    male 28.000      0      0  C.A./SOTON 34068 10.500
# 884         0       3    male 25.000      0      0   SOTON/OQ 392076  7.050
# 885         0       3  female 39.000      0      5            382652 29.125
# 886         0       2    male 27.000      0      0            211536 13.000
# 887         1       1  female 19.000      0      0            112053 30.000
# 888         0       3  female 29.699      1      2        W./C. 6607 23.450
# 889         1       1    male 26.000      0      0            111369 30.000
# 890         0       3    male 32.000      0      0            370376  7.750
#
#            Cabin Embarked  Sex_N  Embarked_N
# 871          D35        S      0           2
# 872  B51 B53 B55        S      1           2
# 873          NaN        S      1           2
# 874          NaN        C      0           0
# 875          NaN        C      0           0
# 876          NaN        S      1           2
# 877          NaN        S      1           2
# 878          NaN        S      1           2
# 879          C50        C      0           0
# 880          NaN        S      0           2
# 881          NaN        S      1           2
# 882          NaN        S      0           2
# 883          NaN        S      1           2
# 884          NaN        S      1           2
# 885          NaN        Q      0           1
# 886          NaN        S      1           2
# 887          B42        S      0           2
# 888          NaN        S      0           2
# 889         C148        C      1           0
# 890          NaN        Q      1           1

# %%
#Turn Age to Age groups
age_bins = [0, 20, 40, 60, np.inf]

# assign categorical labels to the bins
age_labels = ['under 20', '21 to 40', '41 to 60', '61 and above']

# convert the numerical column to categorical
records['Age_Gr'] = pd.cut(records['Age'], bins=age_bins, labels=age_labels, right=True) #if right=False then the intervals are closed on the left side and open on the right side.

# %% [markdown]
# ### **Multivariate analysis with Heatmaps**
#
# Read https://seaborn.pydata.org/generated/seaborn.heatmap.html# and try it yourself

# %%
##write your code to display info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Sex         891 non-null    object
#  3   Age         891 non-null    float64
#  4   SibSp       891 non-null    int64
#  5   Parch       891 non-null    int64
#  6   Ticket      891 non-null    object
#  7   Fare        891 non-null    float64
#  8   Cabin       204 non-null    object
#  9   Embarked    891 non-null    object
#  10  Sex_N       891 non-null    int64
#  11  Embarked_N  891 non-null    int64
#  12  Age_Gr      891 non-null    category
# dtypes: category(1), float64(2), int64(6), object(4)
# memory usage: 84.7+ KB

# %% [markdown]
# Categorical variables may make the heatmap complex and confusing, especially when you have a large complex dataset. One way to limit the variables of interest to examine heatmaps is as follows.

# %%
records_numeric=records.drop(['Sex_N','Embarked_N', 'Age_Gr'], axis=1)

# %% [markdown]
# Read https://seaborn.pydata.org/generated/seaborn.heatmap.html# and try it yourself

# %%
#Let's examine the heatmap now:
sns.heatmap(records_numeric.corr(), cmap="crest", square=True, annot=True, fmt=".1f")
# Out:
# <ipython-input-50-162eb5dd6fa3>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(records_numeric.corr(), cmap="crest", square=True, annot=True, fmt=".1f")
# <Axes: >

# %% [markdown]
# ## **Feature selection**

# %% [markdown]
# This step is to prepare training and test datasets for machine learning modelling - from Topic 3 onwards.

# %%
#Select relevant predictors
features=['Sex_N','Pclass', 'Fare', 'Embarked_N', 'Age', 'SibSp', 'Parch']
X=records[features]

#Select the target variable for prediction
y=records['Survived']

# %%
X.shape
# Out:
# (891, 7)

# %%
y.shape
# Out:
# (891,)

# %% [markdown]
# ## **Split data**

# %%
#import the train_test_split function
from sklearn.model_selection import train_test_split

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)  # 80% training and 20% testing

# %% [markdown]
# # **Task 2: Housing dataset**
#
# **Do it yourself:** Repeat the above steps with the housing dataset to consilidate your learning

# %%
# Import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Import Melbourne housing data**

# %%
url = 'https://raw.githubusercontent.com/ABAL-DU/MIS710-Resources/main/Week%202/Melbourne_housing_FULL.csv'
df = pd.read_csv(url)

# %% [markdown]
# ## **Data at a glance**
# * Print out the first and last 10 records of the datataframe (`head()` and `tail`)
# * What are data type and number of records for each attribute? (`info()`)
# * Are there any missing values? Remove missing values for `Price` column. Compare number of rows before and after removing missing values. (`isnull()`)

# %%
##write your code to print out the first and last data points, hint: just type the name of the dataframe
# Out:
#            Suburb             Address  Rooms Type       Price Method  \
# 0      Abbotsford       68 Studley St      2    h         NaN     SS
# 1      Abbotsford        85 Turner St      2    h 1480000.000      S
# 2      Abbotsford     25 Bloomburg St      2    h 1035000.000      S
# 3      Abbotsford  18/659 Victoria St      3    u         NaN     VB
# 4      Abbotsford        5 Charles St      3    h 1465000.000     SP
# ...           ...                 ...    ...  ...         ...    ...
# 34852  Yarraville         13 Burns St      4    h 1480000.000     PI
# 34853  Yarraville       29A Murray St      2    h  888000.000     SP
# 34854  Yarraville      147A Severn St      2    t  705000.000      S
# 34855  Yarraville    12/37 Stephen St      3    h 1140000.000     SP
# 34856  Yarraville    3 Tarrengower St      2    h 1020000.000     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom   Car  \
# 0             Jellis   3/09/2016     2.500  3067.000  ...     1.000 1.000
# 1             Biggin   3/12/2016     2.500  3067.000  ...     1.000 1.000
# 2             Biggin   4/02/2016     2.500  3067.000  ...     1.000 0.000
# 3             Rounds   4/02/2016     2.500  3067.000  ...     2.000 1.000
# 4             Biggin   4/03/2017     2.500  3067.000  ...     2.000 0.000
# ...              ...         ...       ...       ...  ...       ...   ...
# 34852            Jas  24/02/2018     6.300  3013.000  ...     1.000 3.000
# 34853        Sweeney  24/02/2018     6.300  3013.000  ...     2.000 1.000
# 34854            Jas  24/02/2018     6.300  3013.000  ...     1.000 2.000
# 34855  hockingstuart  24/02/2018     6.300  3013.000  ...       NaN   NaN
# 34856             RW  24/02/2018     6.300  3013.000  ...     1.000 0.000
#
#        Landsize  BuildingArea  YearBuilt               CouncilArea Lattitude  \
# 0       126.000           NaN        NaN        Yarra City Council   -37.801
# 1       202.000           NaN        NaN        Yarra City Council   -37.800
# 2       156.000        79.000   1900.000        Yarra City Council   -37.808
# 3         0.000           NaN        NaN        Yarra City Council   -37.811
# 4       134.000       150.000   1900.000        Yarra City Council   -37.809
# ...         ...           ...        ...                       ...       ...
# 34852   593.000           NaN        NaN  Maribyrnong City Council   -37.811
# 34853    98.000       104.000   2018.000  Maribyrnong City Council   -37.816
# 34854   220.000       120.000   2000.000  Maribyrnong City Council   -37.823
# 34855       NaN           NaN        NaN  Maribyrnong City Council       NaN
# 34856   250.000       103.000   1930.000  Maribyrnong City Council   -37.818
#
#        Longtitude             Regionname Propertycount
# 0         144.996  Northern Metropolitan      4019.000
# 1         144.998  Northern Metropolitan      4019.000
# 2         144.993  Northern Metropolitan      4019.000
# 3         145.012  Northern Metropolitan      4019.000
# 4         144.994  Northern Metropolitan      4019.000
# ...           ...                    ...           ...
# 34852     144.885   Western Metropolitan      6543.000
# 34853     144.888   Western Metropolitan      6543.000
# 34854     144.879   Western Metropolitan      6543.000
# 34855         NaN   Western Metropolitan      6543.000
# 34856     144.894   Western Metropolitan      6543.000
#
# [34857 rows x 21 columns]

# %%
# Execute these codes in separate code cell to see output
##write your code to sample 10 records and print them out, hints: sample()
# Out:
#                Suburb               Address  Rooms Type       Price Method  \
# 29670     Maribyrnong         51 MacEdon St      2    h 1250000.000     PI
# 11630     Murrumbeena  22/41 Murrumbeena Rd      2    u  605000.000     SP
# 13879  West Footscray           17 Braid St      2    h  650000.000     VB
# 25437   Vermont South        16 Salsburg Ct      4    h         NaN     PI
# 21433      Nunawading  7/251 Springfield Rd      2    u         NaN     SN
# 14378       Footscray      22/155 Gordon St      2    u         NaN     PI
# 32110         Seaford         19 Raymond Rd      3    h         NaN      W
# 2546          Burwood        28 Farleigh Av      3    t         NaN      S
# 13709        St Kilda        2/25 Acland St      2    t 1077000.000      S
# 24429   Glen Waverley          6 Dinadan Ct      5    h 1630000.000      S
#
#          SellerG        Date  Distance  Postcode  ...  Bathroom   Car  \
# 29670    Sweeney   6/01/2018     4.300  3032.000  ...     2.000 3.000
# 11630  Fletchers  12/11/2016    12.100  3163.000  ...     2.000 2.000
# 13879    Sweeney   8/04/2017     8.200  3012.000  ...     1.000 1.000
# 25437     Biggin  21/10/2017    17.200  3133.000  ...     2.000 2.000
# 21433      Barry  16/09/2017    15.400  3131.000  ...     1.000 1.000
# 14378    McGrath   1/07/2017     5.100  3011.000  ...     1.000 1.000
# 32110        Ash   3/03/2018    35.400  3198.000  ...     1.000 1.000
# 2546      Buxton  11/03/2017    11.700  3125.000  ...       NaN   NaN
# 13709   Marshall  13/05/2017     6.100  3182.000  ...     1.000 1.000
# 24429  Fletchers  14/10/2017    16.700  3150.000  ...     4.000 2.000
#
#        Landsize  BuildingArea  YearBuilt                CouncilArea Lattitude  \
# 29670   696.000       146.000   1950.000   Maribyrnong City Council   -37.780
# 11630  5289.000        72.000   2013.000     Glen Eira City Council   -37.888
# 13879   452.000           NaN   1950.000   Maribyrnong City Council   -37.804
# 25437  1320.000           NaN        NaN    Whitehorse City Council   -37.862
# 21433       NaN        75.000   1970.000    Manningham City Council   -37.812
# 14378     0.000           NaN        NaN   Maribyrnong City Council   -37.796
# 32110   714.000       109.000   1950.000     Frankston City Council   -38.112
# 2546        NaN           NaN        NaN        Monash City Council       NaN
# 13709   455.000        98.000   1890.000  Port Phillip City Council   -37.864
# 24429   652.000           NaN        NaN        Monash City Council   -37.867
#
#        Longtitude                  Regionname Propertycount
# 29670     144.885        Western Metropolitan      4918.000
# 11630     145.067       Southern Metropolitan      4442.000
# 13879     144.877        Western Metropolitan      5058.000
# 25437     145.193        Eastern Metropolitan      4280.000
# 21433     145.167        Eastern Metropolitan      4973.000
# 14378     144.889        Western Metropolitan      7570.000
# 32110     145.137  South-Eastern Metropolitan      8077.000
# 2546          NaN       Southern Metropolitan      5678.000
# 13709     144.975       Southern Metropolitan     13240.000
# 24429     145.186        Eastern Metropolitan     15321.000
#
# [10 rows x 21 columns]

# %%
##write your code to examine data type and number of records for each attribute, hints: (info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
#  17  Lattitude      26881 non-null  float64
#  18  Longtitude     26881 non-null  float64
#  19  Regionname     34854 non-null  object
#  20  Propertycount  34854 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 5.6+ MB

# %%
#write your code to inspect missing values, hints: isnull()
# Out:
# BuildingArea     21115
# YearBuilt        19306
# Landsize         11810
# Car               8728
# Bathroom          8226
# Bedroom2          8217
# Longtitude        7976
# Lattitude         7976
# Price             7610
# Regionname           3
# CouncilArea          3
# Propertycount        3
# Postcode             1
# Distance             1
# Address              0
# Date                 0
# SellerG              0
# Method               0
# Type                 0
# Rooms                0
# Suburb               0
# dtype: int64

# %%
##write your code to remove missing values for the Price column. Compare number of rows before and after removing missing values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27247 entries, 1 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27247 non-null  object
#  1   Address        27247 non-null  object
#  2   Rooms          27247 non-null  int64
#  3   Type           27247 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         27247 non-null  object
#  6   SellerG        27247 non-null  object
#  7   Date           27247 non-null  object
#  8   Distance       27246 non-null  float64
#  9   Postcode       27246 non-null  float64
#  10  Bedroom2       20806 non-null  float64
#  11  Bathroom       20800 non-null  float64
#  12  Car            20423 non-null  float64
#  13  Landsize       17982 non-null  float64
#  14  BuildingArea   10656 non-null  float64
#  15  YearBuilt      12084 non-null  float64
#  16  CouncilArea    27244 non-null  object
#  17  Lattitude      20993 non-null  float64
#  18  Longtitude     20993 non-null  float64
#  19  Regionname     27244 non-null  object
#  20  Propertycount  27244 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 4.6+ MB

# %% [markdown]
# **Question:** What are implications of removing all missing values in Price?

# %% [markdown]
# ## Numerical analysis and visualisation
#
# * Calculate the mean, median, min, max and std of `Price`, `Landsize` (`describe()`)
# * Plot overall `Price` and `Landsize` distribution using boxplot and histogram (`plot()`)
# * Plot price distribution for each region. and house type

# %% [markdown]
# Now, run and interpret the code and results to the end of this task.

# %%
# Calculate the mean, median, min, max and std of Price, Landsize (describe())
pd.set_option('display.float_format', lambda x: '%.2f' % x) # Set display format for pandas
print(df[['Price', 'Landsize']].describe()) # Select only Price and Landsize columns)
# Out:
#             Price  Landsize
# count    27247.00  17982.00
# mean   1050173.34    593.49
# std     641467.13   3757.27
# min      85000.00      0.00
# 25%     635000.00    219.00
# 50%     870000.00    512.00
# 75%    1295000.00    664.00
# max   11200000.00 433014.00

# %%
# Plot overall Price and Landsize distribution using boxplot and histogram (plot())
# Plot histogram for Price and Landsize columns
for i in ['Price', 'Landsize']:
    sns.histplot(data=df, x=i , bins=100)
    plt.figure()

# Plot boxplot for Price and Landsize columns
for i in ['Price', 'Landsize']:
    sns.boxplot(x=df[i], color='blue')
    plt.figure()

# Plot price distribution for each region. and house type
# Plot price distribution for each region
ax = df['Price'].hist(by=df['Regionname'],figsize=(10,10), bins=100, sharex=True)
plt.figure()

# Plot price distribution for each house type
df['Price'].hist(by=df['Type'],figsize=(10,10), bins=100, sharex=True)
plt.figure()

# %% [markdown]
# ## Categorical data analysis and visualisation
#
# * Count unique values in `Suburb`
# * List unique values in `Regionname`
# * Plot a bar chart of number of sales for top 10 suburbs with the most sales

# %%
# Count unique values in Suburb
df['Suburb'].value_counts()

# List unique values in Regionname
df['Regionname'].value_counts()

# Plot a bar chart of number of sales for top 10 suburbs with the most sales
n = 10 # Assign n_th index
top_10_suburb_list = df['Suburb'].value_counts()[:n].index.tolist() # Return top 10 suburbs with the most sales as a list
df_top_10_suburb = df[df['Suburb'].isin(top_10_suburb_list)] # Make a df contain only top 10 suburbs
df_top_10_suburb['Suburb'].value_counts(ascending=True).plot(kind="barh") # Plot value counts of top 10 suburbs

plt.figure()

# %% [markdown]
# ## Relationship between the columns
# * Price boxplots by Suburbs
# * Histograms by Suburbs

# %%
df_top_10_suburb[['Suburb', 'Price']].boxplot(by='Suburb', vert=False, figsize=(10,6)) # Plot boxplot of prices grouped by top 10 suburbs
df_top_10_suburb['Price'].hist(by=df['Suburb'],figsize=(10,10), bins=100, sharex=True) # Plot price distribution of top 10 suburbs
plt.figure()

# %%
pd.plotting.scatter_matrix(df[['Price', 'Rooms', 'Landsize', 'Car', 'Distance']], alpha=0.2, figsize=(16,16))
# Out:
# array([[<Axes: xlabel='Price', ylabel='Price'>,
#         <Axes: xlabel='Rooms', ylabel='Price'>,
#         <Axes: xlabel='Landsize', ylabel='Price'>,
#         <Axes: xlabel='Car', ylabel='Price'>,
#         <Axes: xlabel='Distance', ylabel='Price'>],
#        [<Axes: xlabel='Price', ylabel='Rooms'>,
#         <Axes: xlabel='Rooms', ylabel='Rooms'>,
#         <Axes: xlabel='Landsize', ylabel='Rooms'>,
#         <Axes: xlabel='Car', ylabel='Rooms'>,
#         <Axes: xlabel='Distance', ylabel='Rooms'>],
#        [<Axes: xlabel='Price', ylabel='Landsize'>,
#         <Axes: xlabel='Rooms', ylabel='Landsize'>,
#         <Axes: xlabel='Landsize', ylabel='Landsize'>,
#         <Axes: xlabel='Car', ylabel='Landsize'>,
#         <Axes: xlabel='Distance', ylabel='Landsize'>],
#        [<Axes: xlabel='Price', ylabel='Car'>,
#         <Axes: xlabel='Rooms', ylabel='Car'>,
#         <Axes: xlabel='Landsize', ylabel='Car'>,
#         <Axes: xlabel='Car', ylabel='Car'>,
#         <Axes: xlabel='Distance', ylabel='Car'>],
#        [<Axes: xlabel='Price', ylabel='Distance'>,
#         <Axes: xlabel='Rooms', ylabel='Distance'>,
#         <Axes: xlabel='Landsize', ylabel='Distance'>,
#         <Axes: xlabel='Car', ylabel='Distance'>,
#         <Axes: xlabel='Distance', ylabel='Distance'>]], dtype=object)

# %% [markdown]
# ## Column wrangling
# * Calculate a new `Price per room` column
# * Calculate a new `Age` column in 2023

# %%
df['Price per room'] = df['Price'] / df['Rooms']
df['Age'] = 2023 - df.YearBuilt

# %% [markdown]
# Let's hypothesise that Age has an effect on Price per room. Let's examine their relationship and discuss the visualisation.

# %%
sns.scatterplot(x=df['Age'], y=df['Price per room'])
# Out:
# <Axes: xlabel='Age', ylabel='Price per room'>

# %% [markdown]
# ## Selection & Indexing
# * Get all the sales made in `Melbourne City Council`. Calculate mean, median, min, max and std for the specified records
# * Get all the sales made in `Manningham City Council` having more than 4 rooms

# %%
# Get all the sales made in Melbourne City Council.
df[df.CouncilArea == 'Melbourne City Council']

# Calculate mean, median, min, max and std for the specified records
df[df.CouncilArea == 'Melbourne City Council']['Price'].describe()

# Get all the sales made in Manningham City Council having more than 4 rooms
df[(df.CouncilArea == 'Melbourne City Council') & (df.Rooms > 4)]
# Out:
#                Suburb           Address  Rooms Type      Price Method  \
# 5792       Kensington  11 Nottingham St      5    h 1710000.00     PI
# 5818       Kensington  11 Nottingham St      5    h 1900000.00     VB
# 5837       Kensington     28 Pridham St      5    h 1001000.00      S
# 7586        Parkville        40 Cade Wy      5    h 1300000.00     PI
# 7590        Parkville        42 Park Dr      8    u 3210000.00      S
# 7598        Parkville  84 Flemington Rd     10    h 2800000.00     VB
# 7781   Port Melbourne  22 Gellibrand Rd      6    h 1800000.00     VB
# 7849   Port Melbourne        146 Dow St      5    h 2350000.00      S
# 12551   Carlton North    271 Canning St      5    h 2450000.00      S
# 12797      Flemington      20 Bryant St      5    h 1550000.00     PI
# 21461  Port Melbourne     101 Stokes St      5    t 2611000.00      S
# 25156      Kensington   54 McCracken St      5    h 1750000.00     VB
# 30687  Port Melbourne    167 Pickles St      5    h 2725000.00     PI
#
#              SellerG        Date  Distance  Postcode  ...  Landsize  \
# 5792          Nelson  10/09/2016      4.20   3031.00  ...    566.00
# 5818          Nelson  16/04/2016      4.20   3031.00  ...    566.00
# 5837         Rendina  24/09/2016      4.20   3031.00  ...    301.00
# 7586          Nelson   4/06/2016      2.60   3052.00  ...       NaN
# 7590           Kelly  10/12/2016      2.60   3052.00  ...       NaN
# 7598          Nelson  16/04/2016      2.60   3052.00  ...       NaN
# 7781            Greg   3/12/2016      3.80   3207.00  ...    353.00
# 7849   hockingstuart  15/10/2016      3.80   3207.00  ...    350.00
# 12551       Woodards  29/04/2017      3.20   3054.00  ...    268.00
# 12797         Nelson  13/05/2017      4.40   3031.00  ...    432.00
# 21461       Marshall  16/09/2017      3.50   3207.00  ...       NaN
# 25156         Nelson  21/10/2017      3.40   3031.00  ...       NaN
# 30687       Marshall   9/12/2017      3.50   3207.00  ...    249.00
#
#        BuildingArea  YearBuilt             CouncilArea  Lattitude  Longtitude  \
# 5792         270.00    1890.00  Melbourne City Council     -37.79      144.93
# 5818         270.00    1890.00  Melbourne City Council     -37.79      144.93
# 5837            NaN        NaN  Melbourne City Council     -37.79      144.93
# 7586            NaN        NaN  Melbourne City Council        NaN         NaN
# 7590            NaN        NaN  Melbourne City Council        NaN         NaN
# 7598            NaN        NaN  Melbourne City Council     -37.79      144.94
# 7781            NaN        NaN  Melbourne City Council     -37.84      144.92
# 7849         173.00    1890.00  Melbourne City Council     -37.84      144.94
# 12551           NaN        NaN  Melbourne City Council     -37.79      144.97
# 12797        200.00    1915.00  Melbourne City Council     -37.79      144.93
# 21461           NaN        NaN  Melbourne City Council     -37.84      144.94
# 25156           NaN        NaN  Melbourne City Council        NaN         NaN
# 30687        210.00    1900.00  Melbourne City Council     -37.84      144.95
#
#                   Regionname  Propertycount  Price per room    Age
# 5792   Northern Metropolitan        5263.00       342000.00 133.00
# 5818   Northern Metropolitan        5263.00       380000.00 133.00
# 5837   Northern Metropolitan        5263.00       200200.00    NaN
# 7586   Northern Metropolitan        2309.00       260000.00    NaN
# 7590   Northern Metropolitan        2309.00       401250.00    NaN
# 7598   Northern Metropolitan        2309.00       280000.00    NaN
# 7781   Southern Metropolitan        8648.00       300000.00    NaN
# 7849   Southern Metropolitan        8648.00       470000.00 133.00
# 12551  Northern Metropolitan        3106.00       490000.00    NaN
# 12797  Northern Metropolitan        3593.00       310000.00 108.00
# 21461  Southern Metropolitan        8648.00       522200.00    NaN
# 25156  Northern Metropolitan        5263.00       350000.00    NaN
# 30687  Southern Metropolitan        8648.00       545000.00 123.00
#
# [13 rows x 23 columns]
